# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
pop_rock = pd.read_csv('pop_rock.csv')
pop_rock
# Out:
#        Unnamed: 0  Unnamed: 0.1        artist_names artists_id  danceability  \
# 0             120           120  ["Boys Don't Cry"]    [80609]         0.749
# 1             121           121  ["Boys Don't Cry"]    [80609]         0.719
# 2             123           123      ["Cap'n Jazz"]   [654543]         0.299
# 3             124           124      ["Cap'n Jazz"]   [654543]         0.437
# 4             125           125      ["Cap'n Jazz"]   [654543]         0.472
# ...           ...           ...                 ...        ...           ...
# 48681       99458         99458          ['ZZ Top']   [690254]         0.276
# 48682       99459         99459          ['ZZ Top']   [690254]         0.700
# 48683       99460         99460          ['ZZ Top']   [690254]         0.709
# 48684       99461         99461          ['ZZ Top']   [690254]         0.552
# 48685       99462         99462          ['ZZ Top']   [690254]         0.546
#
# ...

# %%
pop_rock.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1  danceability        energy       valence  \
# count  48686.000000  48686.000000  48686.000000  48686.000000  48686.000000
# mean   52657.528899  52657.528899      0.511947      0.644496      0.533840
# std    29395.617825  29395.617825      0.152275      0.239681      0.248042
# min      120.000000    120.000000      0.000000      0.000000      0.000000
# 25%    26510.250000  26510.250000      0.405000      0.470000      0.337000
# 50%    54460.500000  54460.500000      0.516000      0.678000      0.535000
# 75%    80056.750000  80056.750000      0.620000      0.851000      0.735000
# max    99462.000000  99462.000000      0.985000      1.000000      0.993000
#
#               tempo      loudness          mode           key  acousticness  \
# count  48686.000000  48686.000000  48686.000000  48686.000000  48686.000000
# mean     123.070211     -9.235921      0.741753      5.171836      0.256987
# ...

# %%
d=pd.DataFrame({'sd': np.std(pop_rock),
                'mean': np.mean(pop_rock)
               })
d
# Out:
#                             sd           mean
# Unnamed: 0        29395.315934   52657.528899
# Unnamed: 0.1      29395.315934   52657.528899
# danceability          0.152273       0.511947
# energy                0.239678       0.644496
# valence               0.248040       0.533840
# tempo                28.745197     123.070211
# loudness              4.230159      -9.235921
# mode                  0.437670       0.741753
# key                   3.533870       5.171836
# acousticness          0.292981       0.256987
# instrumentalness      0.220916       0.091974
# liveness              0.198314       0.217782
# speechiness           0.056196       0.059495
# explicit              0.208925       0.045742
# duration_ms       99138.501022  240212.158156
# popularity           14.080424      40.995851
# year                 15.688441    1987.156061

# %%
d['three_sd_plus']=d['mean'] + 3*d['sd']
d['three_sd_minus']=d['mean'] - 3*d['sd']
d
# Out:
#                             sd           mean  three_sd_plus  three_sd_minus
# Unnamed: 0        29395.315934   52657.528899  140843.476700   -35528.418901
# Unnamed: 0.1      29395.315934   52657.528899  140843.476700   -35528.418901
# danceability          0.152273       0.511947       0.968768        0.055127
# energy                0.239678       0.644496       1.363531       -0.074539
# valence               0.248040       0.533840       1.277959       -0.210279
# tempo                28.745197     123.070211     209.305802       36.834621
# loudness              4.230159      -9.235921       3.454557      -21.926399
# mode                  0.437670       0.741753       2.054764       -0.571258
# key                   3.533870       5.171836      15.773447       -5.429775
# acousticness          0.292981       0.256987       1.135929       -0.621954
# instrumentalness      0.220916       0.091974       0.754720       -0.570773
# ...

# %%
new_df = pop_rock.drop(['artist_names','artists_id','release_date','song_title (censored)', 'Genre'],axis = 1)
for column in d.index:
    new_df = new_df[(new_df[column] > d.loc[column, 'three_sd_minus']) & (new_df[column] < d.loc[column, 'three_sd_plus'])]
new_df
# Out:
#        Unnamed: 0  Unnamed: 0.1  danceability  energy  valence    tempo  \
# 0             120           120         0.749   0.626    0.770  142.565
# 1             121           121         0.719   0.797    0.637  142.567
# 2             123           123         0.299   0.913    0.156  101.059
# 3             124           124         0.437   0.703    0.524   93.134
# 4             125           125         0.472   0.907    0.376  107.294
# ...           ...           ...           ...     ...      ...      ...
# 48679       99456         99456         0.305   0.859    0.330  108.458
# 48681       99458         99458         0.276   0.892    0.715   80.475
# 48682       99459         99459         0.700   0.592    0.906  109.847
# 48683       99460         99460         0.709   0.709    0.863  111.544
# 48685       99462         99462         0.546   0.864    0.863  145.652
#
#        loudness  mode  key  acousticness  instrumentalness  liveness  \
# ...

# %%
colormap=plt.cm.RdBu
plt.figure(figsize=(14,12))
sns.heatmap(new_df.drop(columns=['Unnamed: 0','Unnamed: 0.1','year']).astype(float).corr(),linewidths=0.1,cmap=colormap,vmax=1.0,square=True,annot=True)

# %%
fig,ax=plt.subplots(figsize=(15,7))
sns.lineplot(x='energy',y='loudness',data=new_df,ax=ax)

# %%
new_df = new_df.assign(decade = lambda x: (x.year//10)*10)
new_df = new_df.drop(['Unnamed: 0','Unnamed: 0.1'],axis = 1)
new_df
# Out:
#        danceability  energy  valence    tempo  loudness  mode  key  \
# 0             0.749   0.626    0.770  142.565   -12.426     1    0
# 1             0.719   0.797    0.637  142.567    -6.988     1    0
# 2             0.299   0.913    0.156  101.059    -7.645     1    9
# 3             0.437   0.703    0.524   93.134    -6.958     0    6
# 4             0.472   0.907    0.376  107.294    -6.386     1    7
# ...             ...     ...      ...      ...       ...   ...  ...
# 48679         0.305   0.859    0.330  108.458    -8.213     1    0
# 48681         0.276   0.892    0.715   80.475    -7.035     1   11
# 48682         0.700   0.592    0.906  109.847   -10.434     1   11
# 48683         0.709   0.709    0.863  111.544   -12.023     1    2
# 48685         0.546   0.864    0.863  145.652    -7.632     1    7
#
#        acousticness  instrumentalness  liveness  speechiness  explicit  \
# 0          0.011500          0.567000    0.0558       0.0393         0
# ...

# %%
new_df.to_csv('filtered_pop_rock.csv', index=False)

# %%
twenty = new_df[(new_df["decade"] == 1920)]
thirty = new_df[(new_df["decade"] == 1930)]
fourty = new_df[(new_df["decade"] == 1940)]
fifty = new_df[(new_df["decade"] == 1950)]
sixty = new_df[(new_df["decade"] == 1960)]
seventy = new_df[(new_df["decade"] == 1970)]
eighty = new_df[(new_df["decade"] == 1980)]
ninety = new_df[(new_df["decade"] == 1990)]
two = new_df[(new_df["decade"] == 2000)]
twoten = new_df[(new_df["decade"] == 2010)]
twotwenty = new_df[(new_df["decade"] == 2020)]

# %%
danceability = [twenty["danceability"],thirty["danceability"],fourty["danceability"],fifty["danceability"],sixty["danceability"],seventy["danceability"],eighty["danceability"],ninety["danceability"],two["danceability"],twoten["danceability"],twotwenty["danceability"]]
x_labels = ["1920","1930","1940","1950","1960","1970","1980","1990","2000","2010","2020"]
fig, ax = plt.subplots(figsize=(12, 8))
ax.boxplot(danceability,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Danceability')
ax.set_yticks(np.arange(0, 1, step=0.1))
ax.grid()
plt.show()
# Out:
# C:\Users\yuuna\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
#x_labels = ["acousticness","danceability","duration_ms","energy","explicit","instrumentalness","key","liveness","loudness","mode","popularity","speechiness","tempo","valence"]
valence = [twenty["valence"],thirty["valence"],fourty["valence"],fifty["valence"],sixty["valence"],seventy["valence"],eighty["valence"],ninety["valence"],two["valence"],twoten["valence"],twotwenty["valence"]]

x_labels = ["1920","1930","1940","1950","1960","1970","1980","1990","2000","2010","2020"]
fig, ax = plt.subplots(figsize=(12, 8))
ax.boxplot(valence,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('valence')
ax.set_yticks(np.arange(0, 1, step=0.1))
ax.grid()
plt.show()
# Out:
# C:\Users\yuuna\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
#x_labels = ["acousticness","danceability","duration_ms","energy","explicit","instrumentalness","key","liveness","loudness","mode","popularity","speechiness","tempo","valence"]
energy = [twenty["energy"],thirty["energy"],fourty["energy"],fifty["energy"],sixty["energy"],seventy["energy"],eighty["energy"],ninety["energy"],two["energy"],twoten["energy"],twotwenty["energy"]]

x_labels = ["1920","1930","1940","1950","1960","1970","1980","1990","2000","2010","2020"]
fig, ax = plt.subplots(figsize=(12, 8))
ax.boxplot(energy,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('energy')
ax.set_yticks(np.arange(0, 1, step=0.1))
ax.grid()
plt.show()
# Out:
# C:\Users\yuuna\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
loudness = [twenty["loudness"],thirty["loudness"],fourty["loudness"],fifty["loudness"],sixty["loudness"],seventy["loudness"],eighty["loudness"],ninety["loudness"],two["loudness"],twoten["loudness"],twotwenty["loudness"]]

x_labels = ["1920","1930","1940","1950","1960","1970","1980","1990","2000","2010","2020"]
fig, ax = plt.subplots(figsize=(12, 8))
ax.boxplot(loudness,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('loudness')
ax.set_yticks(np.arange(-70, 15, step=7.0))
ax.grid()
plt.show()
# Out:
# C:\Users\yuuna\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
liveness = [twenty["liveness"],thirty["liveness"],fourty["liveness"],fifty["liveness"],sixty["liveness"],seventy["liveness"],eighty["liveness"],ninety["liveness"],two["liveness"],twoten["liveness"],twotwenty["liveness"]]

x_labels = ["1920","1930","1940","1950","1960","1970","1980","1990","2000","2010","2020"]
fig, ax = plt.subplots(figsize=(12, 8))
ax.boxplot(liveness,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('liveness')
ax.set_yticks(np.arange(0, 1, step=0.1))
ax.grid()
plt.show()
# Out:
# C:\Users\yuuna\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
tempo = [twenty["tempo"],thirty["tempo"],fourty["tempo"],fifty["tempo"],sixty["tempo"],seventy["tempo"],eighty["tempo"],ninety["tempo"],two["tempo"],twoten["tempo"],twotwenty["tempo"]]

x_labels = ["1920","1930","1940","1950","1960","1970","1980","1990","2000","2010","2020"]
fig, ax = plt.subplots(figsize=(12, 8))
ax.boxplot(tempo,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('tempo')
ax.set_yticks(np.arange(0, 250, step=10.0))
ax.grid()
plt.show()
# Out:
# C:\Users\yuuna\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
acousticness = [twenty["acousticness"],thirty["acousticness"],fourty["acousticness"],fifty["acousticness"],sixty["acousticness"],seventy["acousticness"],eighty["acousticness"],ninety["acousticness"],two["acousticness"],twoten["acousticness"],twotwenty["acousticness"]]

x_labels = ["1920","1930","1940","1950","1960","1970","1980","1990","2000","2010","2020"]
fig, ax = plt.subplots(figsize=(12, 8))
ax.boxplot(acousticness,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('acousticness')
ax.set_yticks(np.arange(0, 1, step=0.1))
ax.grid()
plt.show()
# Out:
# C:\Users\yuuna\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
instrumentalness = [twenty["instrumentalness"],thirty["instrumentalness"],fourty["instrumentalness"],fifty["instrumentalness"],sixty["instrumentalness"],seventy["instrumentalness"],eighty["instrumentalness"],ninety["instrumentalness"],two["instrumentalness"],twoten["instrumentalness"],twotwenty["instrumentalness"]]

x_labels = ["1920","1930","1940","1950","1960","1970","1980","1990","2000","2010","2020"]
fig, ax = plt.subplots(figsize=(12, 8))
ax.boxplot(instrumentalness,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('instrumentalness')
ax.set_yticks(np.arange(0, 1, step=0.1))
ax.grid()
plt.show()
# Out:
# C:\Users\yuuna\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
speechiness = [twenty["speechiness"],thirty["speechiness"],fourty["speechiness"],fifty["speechiness"],sixty["speechiness"],seventy["speechiness"],eighty["speechiness"],ninety["speechiness"],two["speechiness"],twoten["speechiness"],twotwenty["speechiness"]]

x_labels = ["1920","1930","1940","1950","1960","1970","1980","1990","2000","2010","2020"]
fig, ax = plt.subplots(figsize=(12, 8))
ax.boxplot(speechiness,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('speechiness')
ax.set_yticks(np.arange(0, 1, step=0.1))
ax.grid()
plt.show()
# Out:
# C:\Users\yuuna\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(16, 10))
sns.set(style="whitegrid")
columns = ["danceability","energy","valence","acousticness","instrumentalness","liveness","speechiness"]
for col in columns:
    x = new_df.groupby("year")[col].mean()
    ax= sns.lineplot(x=x.index,y=x,label=col)
ax.set_title('Pop/Rock Audio Feature')
ax.set_ylabel('Measure')
ax.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
plt.figure(figsize=(16, 8))
sns.set(style="whitegrid")
columns = ["loudness"]
for col in columns:
    x = new_df.groupby("year")[col].mean()
    ax= sns.lineplot(x=x.index,y=x,label=col)
ax.set_title('Pop/Rock Loudness')
ax.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
plt.figure(figsize=(16, 4))
sns.distplot(new_df["danceability"])

# %%
plt.figure(figsize=(16, 4))
sns.distplot(new_df["energy"])

# %%
plt.figure(figsize=(16, 4))
sns.distplot(new_df["loudness"])

# %%
plt.figure(figsize=(16, 4))
sns.distplot(new_df["valence"])

# %%
plt.figure(figsize=(16, 4))
sns.distplot(new_df["year"])

# %%
plt.figure(figsize=(16, 4))
sns.distplot(new_df["popularity"])
